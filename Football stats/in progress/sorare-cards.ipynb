# %% [markdown]
# ### Player cards

# %%
after=""
player_query="""query playerQuery($after:String){ 
  player(slug: "rodrigo-javier-de-paul") { 
    id
    displayName
    cards(
      first: 50
      after: $after
    ) {
      pageInfo {
        endCursor
        hasNextPage
      }
      nodes {
        name
        rarity
        blockchain
        blockchainId
        id
        userOwnersWithRate {
          priceInFiat {
            usd
          }
          from
          transferType
        }
      }
    }
  }
}"""

variables = {
  "after":after
}

# %%
next=True
queries=[]
i=0
while next&(i<200):
        player_r=post(url, json={'query': player_query, 'OperationName': 'SignInMutation', 'variables': variables}, 
                headers=headers,cookies=cookies)
        after=player_r.json()['data']['player']['cards']['pageInfo']['endCursor']
        next=player_r.json()['data']['player']['cards']['pageInfo']['hasNextPage']
        variables = {
        "after":after
        }
        queries.append(player_r.json())
        i+=1
# Out:
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# <ipython-input-95-6984ee23c368> in <module>
#
#       5         player_r=post(url, json={'query': player_query, 'OperationName': 'SignInMutation', 'variables': variables},
#
#       6                 headers=headers,cookies=cookies)
#
# ----> 7         after=player_r.json()['data']['player']['cards']['pageInfo']['endCursor']
#
#       8         next=player_r.json()['data']['player']['cards']['pageInfo']['hasNextPage']
#
#       9         variables = {
#
#
#
# KeyError: 'data'

# %%
player_r.text
# Out:
# '{"error":"Retry later"}'

# %%
len(queries)
# Out:
# 18

# %%
queries[1]
# Out:
# {'data': {'player': {'id': 'Player:f467d965-b130-47f7-9e8d-6d830821e5df',
#    'displayName': 'Rodrigo De Paul',
#    'cards': {'pageInfo': {'endCursor': 'WyJlYTljZmZmNy01ZWFjLTRlNDItYTVjOS03NmE1NzhhODViMTkiXQ',
#      'hasNextPage': True},
#     'nodes': [{'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e93738bf-b999-42c4-9273-b5e828210cec',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-10T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:e93ac7e6-2a02-4bc8-acc2-315fc38cb5c9',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-09-28T09:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9451584-d6a8-47c2-ae7e-e7a4847ddb73',
#       'userOwnersWithRate': []},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e94dbb71-7a5e-4874-923a-98d0ca10bf13',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-10-09T15:58:07Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:e950d1f0-62da-47fd-8adf-130b0dbfd8fa',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-02T09:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:e962f9cf-ffc5-4c86-8148-6209573e9767',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-09T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:e965a388-1d2b-4cb2-9809-d4b89a23780a',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-23T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e96bfb68-b378-426e-af19-b56d58ed8db6',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-09-09T10:45:43Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e98290dc-2464-4bb5-bbc2-7bdc522821cf',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-21T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:e9847c62-4b9b-4fb8-b039-040ecce164ba',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-10-26T09:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e99128fb-406b-4b7f-a7e1-3e671d13932c',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-29T06:01:38Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e992ccae-6410-4b1d-a09d-e595bfc3b6f4',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-09-08T11:46:30Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9950a88-2e9d-4e39-9689-733e78dcc7f7',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-10T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9a5f047-ce78-403f-a54a-b875e8ede7fd',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-28T09:46:34Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9a94f99-c00f-4b0c-9064-38d342245dc6',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-03T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2020-21 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9ab5dd0-9981-4bf6-a78a-49e7a4c4fc2f',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-05-15T22:37:21Z',
#         'transferType': 'draft'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9ab68c3-dcc3-4dab-9ddd-e3051c9826c3',
#       'userOwnersWithRate': []},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9afcaec-f6b3-4f63-906a-6fbc2197238d',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-21T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9b5c957-5fc5-4a66-ae9f-c9a69189b623',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-14T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:e9bb2310-ba01-48e8-abc8-64b569dd0f65',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-09T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:e9bef5b4-5f5d-48d3-b248-5b09728fddff',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-23T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9c35003-00e7-4dfa-bc2a-7d510ff298c6',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-30T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:e9c84b0f-f5f8-4846-adf2-c42549f8ab06',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-10-22T09:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9dbac03-814e-4b78-b23a-4df60f4644da',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-10-15T18:40:04Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9e93066-db90-4ec0-96fb-3b805e3a3ea5',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-10-02T13:30:36Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9eef299-18b0-4fbc-9993-118d2eafd7c0',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-14T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9fc99ed-1e86-4916-b8d4-ac259e3d8c0c',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-19T09:34:32Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:e9fd3636-177f-4298-a001-13c3c4a0cb6b',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-16T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9fe555a-1d9e-4532-9cf0-2da83a8681da',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-17T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:e9ff725d-4407-4e82-8741-ccbb8fc72f4c',
#       'userOwnersWithRate': []},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:ea01a28a-6219-4892-b7f7-41fcee89f295',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-09T05:51:54Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:ea08509c-6c9e-4ccb-ae28-13a1eca61b9c',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-05T09:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:ea08675a-ff93-4013-bd67-0a913ca737e4',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-19T18:53:36Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:ea0a97f5-9101-4536-bbf4-2b53332dc585',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-21T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:ea157d42-1725-49a4-9c25-d37fb3194baf',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-12T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:ea1c08f4-f06f-4020-b369-67b8acd1992c',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-21T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:ea1fbea2-291a-4c82-9333-c5ff727b8552',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-05T09:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:ea27f110-a7de-46f5-82ce-c217947063cb',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-10T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:ea3849f1-8588-45e7-8f99-a79c5e07fa92',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-21T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:ea45c120-ef07-4f4d-a593-a16c8fbb7fd2',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-10-29T09:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Rare 20/100',
#       'rarity': 'rare',
#       'blockchain': 'starkware',
#       'blockchainId': '47390321324257921717257886919866640212495413720261905018691106849279032297917',
#       'id': 'Card:ea4831a4-e09b-4016-ae8e-f2195e497ad5',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 1273.257},
#         'from': '2021-10-31T18:20:57Z',
#         'transferType': 'single_buy_offer'},
#        {'priceInFiat': {'usd': 0.0},
#         'from': '2021-10-26T14:28:38Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:ea542a17-bec7-4f1d-921d-e1917721d138',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-07T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:ea55ffd5-611e-420c-bfe5-82908c6a585b',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-16T01:13:27Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:ea5c91b0-81e4-4d5d-be56-ddc66c01e72e',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-12T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:ea6009d2-65f2-445c-9f9c-c56265c2b134',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-17T10:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:ea6ceb03-650a-43ee-b9be-3b1375984272',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-11-13T17:43:19Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:ea781650-a90b-4dba-88bf-e0c5b5235c56',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-09-21T09:59:59Z',
#         'transferType': 'reward'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:ea888c6d-86b7-41c1-b171-0a7cb9cc55e2',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-12-19T12:20:27Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'no_blockchain',
#       'blockchainId': None,
#       'id': 'Card:ea9155ac-259b-4724-9132-33a7cc8b42c7',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-10-22T06:52:53Z',
#         'transferType': 'onboarding'}]},
#      {'name': 'Rodrigo De Paul 2021-22 • Common',
#       'rarity': 'common',
#       'blockchain': 'starkware',
#       'blockchainId': None,
#       'id': 'Card:ea9cfff7-5eac-4e42-a5c9-76a578a85b19',
#       'userOwnersWithRate': [{'priceInFiat': {'usd': 0.0},
#         'from': '2021-10-29T09:59:59Z',
#         'transferType': 'reward'}]}]}}}}

# %%
df=pd.DataFrame()
for i in queries:
    df_cards=pd.json_normalize(i,record_path=['data','player','cards','nodes'])
    df=df.append(df_cards)

# %%
card_detail=df[df.rarity!='common'].explode(column='userOwnersWithRate').reset_index(drop=True)
price_detail=pd.json_normalize(card_detail['userOwnersWithRate'])
card_detail=card_detail.join(price_detail)
sns.boxplot(data=card_detail,x='rarity',y='priceInFiat.usd')
# Out:
# <AxesSubplot:xlabel='rarity', ylabel='priceInFiat.usd'>

# %%
card_detail['from']=pd.to_datetime(card_detail['from'])
sns.scatterplot(data=card_detail,x='from',y='priceInFiat.usd',hue='rarity')
plt.grid()
plt.xticks(rotation=80);
